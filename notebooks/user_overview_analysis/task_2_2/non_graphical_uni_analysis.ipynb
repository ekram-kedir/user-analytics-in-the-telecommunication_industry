# %%
import os
import sys
import numpy as np

notebook_name = 'non_graphical_uni_analysis.ipynb'

current_dir = os.path.dirname(os.path.abspath(notebook_name))
parent_dir = os.path.abspath(os.path.join(current_dir, '..', '..', '..'))


sys.path.insert(1, parent_dir)
from src.data_processer import TelecomDataProcessor

# %%
# Replace 'your_conn_params' with your actual connection parameters
conn_params = {
    'host': 'localhost',
    'port': 5432,
    'user': 'ekru',
    'password': 'ekram12345',
    'database': 'tellco',
}

telecom_data_processor = TelecomDataProcessor(conn_params)

# %%
df = telecom_data_processor.load_dataset()
# Out:
# /home/ekram/Desktop/week-1/user_analytics_in_the_telecommunication_industry/src/data_processer.py:63: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql_query, conn)

# %%
cleaned_df = telecom_data_processor.clean_dataset(df)
# Out:
# /home/ekram/Desktop/week-1/user_analytics_in_the_telecommunication_industry/src/data_processer.py:88: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.fillna(df.mean(), inplace=True)
#            Bearer Id            Start  Start ms              End     End ms  \
# 0       1.311448e+19   4/4/2019 12:01  770.0000  4/25/2019 14:35  662.00000
# 1       1.311448e+19   4/9/2019 13:04  235.0000   4/25/2019 8:15  606.00000
# 2       1.311448e+19   4/9/2019 17:42    1.0000  4/25/2019 11:58  652.00000
# 3       1.311448e+19   4/10/2019 0:31  486.0000   4/25/2019 7:36  171.00000
# 4       1.311448e+19  4/12/2019 20:10  565.0000  4/25/2019 10:40  954.00000
# ...              ...              ...       ...              ...        ...
# ...

# %%
telecom_data_processor.overview_analysis(cleaned_df)
# Out:
#           BEARER_ID       START_MS         END_MS     DUR._(MS)          IMSI  \
# count  1.500010e+05  150001.000000  150001.000000  1.500010e+05  1.500010e+05
# mean   1.013887e+19     499.188200     498.800880  1.046086e+05  2.082016e+14
# std    2.883600e+18     288.610872     288.096693  8.103735e+04  2.144722e+10
# min    6.917538e+18       0.000000       0.000000  7.142000e+03  2.040471e+14
# 25%    7.349883e+18     250.000000     251.000000  5.744200e+04  2.082014e+14
# 50%    7.349883e+18     499.000000     500.000000  8.639900e+04  2.082015e+14
# 75%    1.304243e+19     749.000000     750.000000  1.324300e+05  2.082018e+14
# max    1.318654e+19     999.000000     999.000000  1.859336e+06  2.140743e+14
#
#        MSISDN/NUMBER          IMEI  AVG_RTT_DL_(MS)  AVG_RTT_UL_(MS)  \
# count   1.500010e+05  1.500010e+05    150001.000000    150001.000000
# mean    4.188282e+10  4.847455e+13       109.795706        17.662883
# ...

# %%
# Select quantitative columns
quantitative_columns = [
    'DUR._(MS)',
    'AVG_RTT_DL_(MS)',
    'AVG_RTT_UL_(MS)',
    'AVG_BEARER_TP_DL_(KBPS)',
    'AVG_BEARER_TP_UL_(KBPS)',
    'TCP_DL_RETRANS._VOL_(BYTES)',
    'TCP_UL_RETRANS._VOL_(BYTES)',
    'DL_TP_<_50_KBPS_(%)',
    '50_KBPS_<_DL_TP_<_250_KBPS_(%)',
    '250_KBPS_<_DL_TP_<_1_MBPS_(%)',
    'DL_TP_>_1_MBPS_(%)',
    'UL_TP_<_10_KBPS_(%)',
    '10_KBPS_<_UL_TP_<_50_KBPS_(%)',
    '50_KBPS_<_UL_TP_<_300_KBPS_(%)',
    'UL_TP_>_300_KBPS_(%)',
    'ACTIVITY_DURATION_DL_(MS)',
    'ACTIVITY_DURATION_UL_(MS)',
    'NB_OF_SEC_WITH_125000B_<_VOL_DL',
    'NB_OF_SEC_WITH_1250B_<_VOL_UL_<_6250B',
    'NB_OF_SEC_WITH_31250B_<_VOL_DL_<_125000B',
    'NB_OF_SEC_WITH_37500B_<_VOL_UL',
    'NB_OF_SEC_WITH_6250B_<_VOL_DL_<_31250B',
    'NB_OF_SEC_WITH_6250B_<_VOL_UL_<_37500B',
    'NB_OF_SEC_WITH_VOL_DL_<_6250B',
    'NB_OF_SEC_WITH_VOL_UL_<_1250B',
    'SOCIAL_MEDIA_DL_(BYTES)',
    'SOCIAL_MEDIA_UL_(BYTES)',
    'YOUTUBE_DL_(BYTES)',
    'YOUTUBE_UL_(BYTES)',
    'NETFLIX_DL_(BYTES)',
    'NETFLIX_UL_(BYTES)',
    'GOOGLE_DL_(BYTES)',
    'GOOGLE_UL_(BYTES)',
    'EMAIL_DL_(BYTES)',
    'EMAIL_UL_(BYTES)',
    'GAMING_DL_(BYTES)',
    'GAMING_UL_(BYTES)',
    'OTHER_DL_(BYTES)',
    'OTHER_UL_(BYTES)',
    'TOTAL_DL_(BYTES)',
    'TOTAL_UL_(BYTES)'
]


# Compute dispersion parameters for each column
dispersion_results = {}
for column in quantitative_columns:
    data_range = np.ptp(df[column])
    variance = np.var(df[column])
    std_deviation = np.std(df[column])

    dispersion_results[column] = {
        'Range': data_range,
        'Variance': variance,
        'Standard Deviation': std_deviation
    }

# Display the results
for column, results in dispersion_results.items():
    print(f"\nDispersion Parameters for {column}:")
    print(f"Range: {results['Range']}")
    print(f"Variance: {results['Variance']}")
    print(f"Standard Deviation: {results['Standard Deviation']}")
# Out:
# Dispersion Parameters for DUR._(MS):
# Range: 1852194.0
# Variance: 6567008534.276451
# Standard Deviation: 81037.0812299928
#
# Dispersion Parameters for AVG_RTT_DL_(MS):
# Range: 96923.0
# Variance: 312862.08045297954
# Standard Deviation: 559.340755222592
#
# Dispersion Parameters for AVG_RTT_UL_(MS):
# Range: 7120.0
# Variance: 5856.791617874987
# Standard Deviation: 76.52967802019677
#
# Dispersion Parameters for AVG_BEARER_TP_DL_(KBPS):
# Range: 378160.0
# Variance: 574643298.8449316
# Standard Deviation: 23971.718729472268
#
# Dispersion Parameters for AVG_BEARER_TP_UL_(KBPS):
# Range: 58613.0
# Variance: 21393628.254320335
# Standard Deviation: 4625.324664747366
#
# Dispersion Parameters for TCP_DL_RETRANS._VOL_(BYTES):
# Range: 4294425568.0
# Variance: 1.3744088657420438e+16
# Standard Deviation: 117235185.23643163
#
# Dispersion Parameters for TCP_UL_RETRANS._VOL_(BYTES):
# Range: 2908226005.0
# Variance: 248885630156273.16
# Standard Deviation: 15776109.474654173
#
# ...
